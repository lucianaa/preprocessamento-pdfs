# %%
# CÉLULA 1: CONFIGURAÇÃO DO AMBIENTE
import sys
import os
import json
import glob

notebook_dir = os.getcwd() 
PROJECT_ROOT_PATH = os.path.abspath(os.path.join(notebook_dir, '..'))
SRC_PATH = os.path.join(PROJECT_ROOT_PATH, "src")

if SRC_PATH not in sys.path:
    sys.path.append(SRC_PATH)
    print(f"Adicionado ao sys.path: {SRC_PATH}")

try:
    from table_pipeline.table_runner import run_extraction_pipeline
    from integration import _format_table_for_final_json
    print("Sucesso: Módulos 'table_runner' e 'integration' (formatador) importados.")
    
except ImportError as e:
    print(f"!!! ERRO DE IMPORTAÇÃO !!!")
    print(f"Verifique se 'table_pipeline/' e 'integration.py' estão na pasta: {SRC_PATH}")
    print(f"Erro original: {e}")
# Out:
# Sucesso: Módulos 'table_runner' e 'integration' (formatador) importados.

# %%
# CÉLULA 2: DEFINIÇÃO DOS CAMINHOS DE ENTRADA/SAÍDA

PDF_INPUT_DIRECTORY = os.path.join(PROJECT_ROOT_PATH, "data", "input")
JSON_OUTPUT_DIRECTORY = os.path.join(PROJECT_ROOT_PATH, "data", "output")

os.makedirs(JSON_OUTPUT_DIRECTORY, exist_ok=True) # Cria a pasta 'output' se não existir

if not os.path.exists(PDF_INPUT_DIRECTORY):
    print(f"!!! ALERTA: Pasta de PDFs não encontrada: {PDF_INPUT_DIRECTORY}")

print(f"Lendo PDFs de: {PDF_INPUT_DIRECTORY}")
print(f"Lendo e Editando/Criando JSONs em: {JSON_OUTPUT_DIRECTORY}")
# Out:
# Lendo PDFs de: C:\Users\extre\preprocessamento-pdfs\data\input
# Lendo e Editando/Criando JSONs em: C:\Users\extre\preprocessamento-pdfs\data\output

# %%
# CÉLULA 3: EXECUÇÃO (com RESUMO LIMPO no final)

print("\n--- INICIANDO PIPELINE DE INTEGRAÇÃO (Modo Padrão: 'tables') ---")

pdf_files_to_process = glob.glob(os.path.join(PDF_INPUT_DIRECTORY, "*.pdf"))

if not pdf_files_to_process:
    print(f"Nenhum PDF encontrado em {PDF_INPUT_DIRECTORY}. Fim da execução.")
else:
    print(f"Encontrados {len(pdf_files_to_process)} PDFs para processar...")

resumo_geral = []

# Loop principal: 1 PDF por vez
for pdf_path in pdf_files_to_process:
    pdf_name = os.path.basename(pdf_path)
    pdf_basename = os.path.splitext(pdf_name)[0]
    
    # Imprime apenas o início do processamento
    print(f"\n--- Processando: {pdf_name} ---")

    # Variáveis para guardar os detalhes do resumo
    json_alvo = ""
    status_acao_json = ""
    tabelas_adicionadas = 0
    status_limpeza = "Não"
    status_final = "FALHA"
    erro_msg = None

    try:
        # --- ETAPA A: Encontrar ou Criar o JSON Base ---
        jsonl_name = f"{pdf_basename}_output.jsonl"
        json_name = f"{pdf_basename}_output.json"
        
        jsonl_path = os.path.join(JSON_OUTPUT_DIRECTORY, jsonl_name)
        json_path = os.path.join(JSON_OUTPUT_DIRECTORY, json_name)
        
        path_to_use = None
        base_json_data = {} 

        if os.path.exists(jsonl_path):
            path_to_use = jsonl_path
            json_alvo = jsonl_name
            status_acao_json = "Editado"
            try:
                with open(path_to_use, 'r', encoding='utf-8') as f:
                    base_json_data = json.load(f)
            except json.JSONDecodeError:
                status_acao_json = "Corrompido (Recriado)"
                base_json_data = {}

        elif os.path.exists(json_path):
            path_to_use = json_path
            json_alvo = json_name
            status_acao_json = "Editado"
            try:
                with open(path_to_use, 'r', encoding='utf-8') as f:
                    base_json_data = json.load(f)
            except json.JSONDecodeError:
                status_acao_json = "Corrompido (Recriado)"
                base_json_data = {}
                
        else:
            path_to_use = jsonl_path
            json_alvo = jsonl_name
            status_acao_json = "Criado (Novo)"
            base_json_data = {}

        # --- ETAPA B: Extrair as Tabelas (Nossa Tarefa) ---
        # (Esta função ainda vai imprimir os logs internos dela, como "Nenhuma tabela encontrada...")
        raw_table_data = run_extraction_pipeline(pdf_path=pdf_path)

        # --- ETAPA C: Formatar as Tabelas (Nossa Tarefa) ---
        formatted_tables_list = []
        
        for table in raw_table_data.get("calendarios", []):
            formatted_tables_list.append(_format_table_for_final_json(table, "calendar"))
        for table in raw_table_data.get("horarios", []):
            formatted_tables_list.append(_format_table_for_final_json(table, "horario"))
        for ppc_page_data in raw_table_data.get("ppc_data", []):
            for sub_tabela in ppc_page_data.get("parsed_data_list", []):
                formatted_tables_list.append(_format_table_for_final_json(sub_tabela, "ppc"))
        
        tabelas_adicionadas = len(formatted_tables_list)

        # --- ETAPA D: INTEGRAR NA CHAVE "tables" (plural) ---
        if "tables" not in base_json_data or not isinstance(base_json_data.get("tables"), list):
            base_json_data["tables"] = formatted_tables_list
        else:
            base_json_data["tables"].extend(formatted_tables_list)

        if "table" in base_json_data:
            status_limpeza = "Sim" # Marca que a limpeza foi feita
            del base_json_data["table"]

        # --- ETAPA E: Salvar o Resultado (Sobrescrevendo ou Criando) ---
        with open(path_to_use, 'w', encoding='utf-8') as f:
            json.dump(base_json_data, f, indent=4, ensure_ascii=False)
        
        status_final = "SUCESSO"

    except Exception as e:
        print(f"!!! [ERRO GERAL] Falha grave ao processar {pdf_name}: {e} !!!")
        erro_msg = str(e)

    # --- Guarda os dados do resumo para este arquivo ---
    resumo_geral.append({
        "pdf": pdf_name,
        "json": json_alvo,
        "status": status_final,
        "tabelas_add": tabelas_adicionadas,
        "acao_json": status_acao_json,
        "limpeza": status_limpeza,
        "erro": erro_msg
    })

# --- Fim do Loop ---

# --- IMPRESSÃO DO RESUMO FINAL ---

print("\n\n" + "="*50)
print("--- PROCESSAMENTO DE INTEGRAÇÃO CONCLUÍDO ---")
print("="*50)

sucesso_count = sum(1 for r in resumo_geral if r["status"] == "SUCESSO")
falha_count = len(resumo_geral) - sucesso_count

print(f"Sucesso: {sucesso_count} arquivos")
print(f"Falhas:  {falha_count} arquivos")

print("\n--- RESUMO DETALHADO POR ARQUIVO ---")

for r in resumo_geral:
    if r["status"] == "SUCESSO":
        print(f"\n[SUCESSO] {r['pdf']}")
        print(f"  - JSON Alvo:   {r['json']} ({r['acao_json']})")
        print(f"  - Tabelas Add: {r['tabelas_add']}")
        print(f"  - Limpeza ('table' singular): {r['limpeza']}")
    else:
        print(f"\n[FALHA] {r['pdf']}")
        print(f"  - JSON Alvo:   {r['json']}")
        print(f"  - Erro: {r['erro']}")
# Out:
# --- INICIANDO PIPELINE DE INTEGRAÇÃO (Modo Padrão: 'tables') ---
# Encontrados 7 PDFs para processar...
#
# --- Processando: Ciencia-da-computacao-01-2025_com_sala_MkIII.pdf ---
# Iniciando [Table Pipeline] para: C:\Users\extre\preprocessamento-pdfs\data\input\Ciencia-da-computacao-01-2025_com_sala_MkIII.pdf
#   [Table Pipeline] Página 1/7 -> Tipo: horario
# --- [horario.py] Processando Página 1 ---
#   [horario.py] Metadados encontrados: 20 INGRESSANTES (MATUTINO)
#   [horario.py] Sala padrão detectada: 'P2 – Sala 7'
#   [horario.py] Tabela da página 1 processada com sucesso.
#   [Table Pipeline] Página 2/7 -> Tipo: horario
# --- [horario.py] Processando Página 2 ---
#   [horario.py] Metadados encontrados: 30 (MATUTINO)
#   [horario.py] Sala padrão detectada: 'P2 - Sala 9'
#   [horario.py] Tabela da página 2 processada com sucesso.
#   [Table Pipeline] Página 3/7 -> Tipo: horario
# --- [horario.py] Processando Página 3 ---
#   [horario.py] Metadados encontrados: 50 PERÍODO (VESPERTINO)
#   [horario.py] Sala padrão detectada: 'P2 – sala 9'
#   [horario.py] Tabela da página 3 processada com sucesso.
#   [Table Pipeline] Página 4/7 -> Tipo: horario
# --- [horario.py] Processando Página 4 ---
#   [horario.py] Metadados encontrados: 70 PERÍODO (MATUTINO)
#   [horario.py] Sala padrão detectada: 'P2 – Sala 8'
#   [horario.py] Tabela da página 4 processada com sucesso.
#   [Table Pipeline] Página 5/7 -> Tipo: horario
# --- [horario.py] Processando Página 5 ---
#   [horario.py] Metadados encontrados: 90 PERÍODO / Optativas
#   [horario.py] Sala padrão detectada: 'P2 – Sala 9'
#   [horario.py] Tabela da página 5 processada com sucesso.
#   [Table Pipeline] Página 6/7 -> Tipo: horario
# --- [horario.py] Processando Página 6 ---
#   [horario.py] Metadados encontrados: Optativas (Vespertino)
#   [horario.py] Sala padrão detectada: 'P2 – Sala 7'
#   [horario.py] Tabela da página 6 processada com sucesso.
#   [Table Pipeline] Página 7/7 -> Tipo: horario
# --- [horario.py] Processando Página 7 ---
#   [horario.py] Metadados encontrados: RE-OFERTAS  (Vespertino)
#   [horario.py] Sala padrão detectada: 'P2 – sala 7'
#   [horario.py] Tabela da página 7 processada com sucesso.
# Concluído [Table Pipeline]. Resultados: {'horarios': 7}
#
# --- Processando: Estatuto - Fevereiro 2025_.pdf ---
# Iniciando [Table Pipeline] para: C:\Users\extre\preprocessamento-pdfs\data\input\Estatuto - Fevereiro 2025_.pdf
#   [Table Pipeline] Página 1/52 -> Tipo: unknown
#   [Table Pipeline] Página 2/52 -> Tipo: history_log
#   [Table Pipeline] Página 3/52 -> Tipo: unknown
#   [Table Pipeline] Página 4/52 -> Tipo: unknown
#   [Table Pipeline] Página 5/52 -> Tipo: unknown
#   [Table Pipeline] Página 6/52 -> Tipo: unknown
#   [Table Pipeline] Página 7/52 -> Tipo: unknown
#   [Table Pipeline] Página 8/52 -> Tipo: unknown
#   [Table Pipeline] Página 9/52 -> Tipo: unknown
#   [Table Pipeline] Página 10/52 -> Tipo: unknown
#   [Table Pipeline] Página 11/52 -> Tipo: unknown
#   [Table Pipeline] Página 12/52 -> Tipo: unknown
#   [Table Pipeline] Página 13/52 -> Tipo: unknown
#   [Table Pipeline] Página 14/52 -> Tipo: unknown
#   [Table Pipeline] Página 15/52 -> Tipo: unknown
#   [Table Pipeline] Página 16/52 -> Tipo: unknown
#   [Table Pipeline] Página 17/52 -> Tipo: unknown
#   [Table Pipeline] Página 18/52 -> Tipo: unknown
#   [Table Pipeline] Página 19/52 -> Tipo: unknown
#   [Table Pipeline] Página 20/52 -> Tipo: unknown
#   [Table Pipeline] Página 21/52 -> Tipo: unknown
#   [Table Pipeline] Página 22/52 -> Tipo: unknown
#   [Table Pipeline] Página 23/52 -> Tipo: unknown
#   [Table Pipeline] Página 24/52 -> Tipo: unknown
#   [Table Pipeline] Página 25/52 -> Tipo: unknown
#   [Table Pipeline] Página 26/52 -> Tipo: unknown
#   [Table Pipeline] Página 27/52 -> Tipo: unknown
#   [Table Pipeline] Página 28/52 -> Tipo: unknown
#   [Table Pipeline] Página 29/52 -> Tipo: unknown
#   [Table Pipeline] Página 30/52 -> Tipo: unknown
#   [Table Pipeline] Página 31/52 -> Tipo: unknown
#   [Table Pipeline] Página 32/52 -> Tipo: unknown
#   [Table Pipeline] Página 33/52 -> Tipo: unknown
#   [Table Pipeline] Página 34/52 -> Tipo: unknown
#   [Table Pipeline] Página 35/52 -> Tipo: unknown
#   [Table Pipeline] Página 36/52 -> Tipo: unknown
#   [Table Pipeline] Página 37/52 -> Tipo: unknown
#   [Table Pipeline] Página 38/52 -> Tipo: unknown
#   [Table Pipeline] Página 39/52 -> Tipo: unknown
#   [Table Pipeline] Página 40/52 -> Tipo: unknown
#   [Table Pipeline] Página 41/52 -> Tipo: unknown
#   [Table Pipeline] Página 42/52 -> Tipo: unknown
#   [Table Pipeline] Página 43/52 -> Tipo: unknown
#   [Table Pipeline] Página 44/52 -> Tipo: unknown
#   [Table Pipeline] Página 45/52 -> Tipo: unknown
#   [Table Pipeline] Página 46/52 -> Tipo: unknown
#   [Table Pipeline] Página 47/52 -> Tipo: unknown
#   [Table Pipeline] Página 48/52 -> Tipo: unknown
#   [Table Pipeline] Página 49/52 -> Tipo: unknown
#   [Table Pipeline] Página 50/52 -> Tipo: unknown
#   [Table Pipeline] Página 51/52 -> Tipo: unknown
#   [Table Pipeline] Página 52/52 -> Tipo: unknown
# Concluído [Table Pipeline]. Resultados: {}
#
# --- Processando: Estágio.pdf ---
# Iniciando [Table Pipeline] para: C:\Users\extre\preprocessamento-pdfs\data\input\Estágio.pdf
#   [Table Pipeline] Página 1/13 -> Tipo: unknown
#   [Table Pipeline] Página 2/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 3/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 4/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 5/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 6/13 -> Tipo: unknown
#   [Table Pipeline] Página 7/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 8/13 -> Tipo: unknown
#   [Table Pipeline] Página 9/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 10/13 -> Tipo: unknown
#   [Table Pipeline] Página 11/13 -> Tipo: unknown
#   [Table Pipeline] Página 12/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 13/13 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
# Concluído [Table Pipeline]. Resultados: {}
#
# --- Processando: PPCBCC2019.pdf ---
# Iniciando [Table Pipeline] para: C:\Users\extre\preprocessamento-pdfs\data\input\PPCBCC2019.pdf
#   [Table Pipeline] Página 1/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/1 na página 1...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 1 tabelas. Tipos detectados: ppc_tabela_desconhecida
#   [Table Pipeline] Página 2/103 -> Tipo: unknown
#   [Table Pipeline] Página 3/103 -> Tipo: unknown
#   [Table Pipeline] Página 4/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 5/103 -> Tipo: unknown
#   [Table Pipeline] Página 6/103 -> Tipo: unknown
#   [Table Pipeline] Página 7/103 -> Tipo: unknown
#   [Table Pipeline] Página 8/103 -> Tipo: unknown
#   [Table Pipeline] Página 9/103 -> Tipo: unknown
#   [Table Pipeline] Página 10/103 -> Tipo: unknown
#   [Table Pipeline] Página 11/103 -> Tipo: unknown
#   [Table Pipeline] Página 12/103 -> Tipo: unknown
#   [Table Pipeline] Página 13/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 14/103 -> Tipo: unknown
#   [Table Pipeline] Página 15/103 -> Tipo: unknown
#   [Table Pipeline] Página 16/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 17/103 -> Tipo: unknown
#   [Table Pipeline] Página 18/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 19/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
# C:\Users\extre\AppData\Local\Programs\Python\Python313\Lib\site-packages\camelot\utils.py:1217: UserWarning:   (546.36, 549.36) does not lie in column range (50.14801655078598, 546.009939540508)
#   warnings.warn(
# C:\Users\extre\AppData\Local\Programs\Python\Python313\Lib\site-packages\camelot\utils.py:1217: UserWarning:   (546.36, 549.36) does not lie in column range (50.149422517382106, 546.009939540508)
#   warnings.warn(
# C:\Users\extre\AppData\Local\Programs\Python\Python313\Lib\site-packages\camelot\utils.py:1217: UserWarning:   (546.36, 549.36) does not lie in column range (50.14895386185007, 546.009939540508)
#   warnings.warn(
#       [ppc.py] Processando Tabela 1/3 na página 19...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 19...
#       [ppc.py] -> Tabela 2 identificada como: 'ppc_matriz_curricular' (ou optativa)
#       [ppc.py] -> SUCESSO: Parser 'ppc_matriz_curricular' retornou dados.
#       [ppc.py] Processando Tabela 3/3 na página 19...
#       [ppc.py] -> Tabela 3 identificada como: 'ppc_matriz_curricular' (ou optativa)
#       [ppc.py] -> SUCESSO: Parser 'ppc_matriz_curricular' retornou dados.
#     -> SUCESSO: 'ppc.py' retornou 2 tabela(s). Adicionando aos resultados.
#   [Table Pipeline] Página 20/103 -> Tipo: unknown
#   [Table Pipeline] Página 21/103 -> Tipo: unknown
#   [Table Pipeline] Página 22/103 -> Tipo: unknown
#   [Table Pipeline] Página 23/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/1 na página 23...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 1 tabelas. Tipos detectados: ppc_tabela_desconhecida
#   [Table Pipeline] Página 24/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/1 na página 24...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_matriz_curricular' (ou optativa)
#       [ppc.py] -> SUCESSO: Parser 'ppc_optativas' retornou dados.
#     -> SUCESSO: 'ppc.py' retornou 1 tabela(s). Adicionando aos resultados.
#   [Table Pipeline] Página 25/103 -> Tipo: unknown
#   [Table Pipeline] Página 26/103 -> Tipo: unknown
#   [Table Pipeline] Página 27/103 -> Tipo: unknown
#   [Table Pipeline] Página 28/103 -> Tipo: unknown
#   [Table Pipeline] Página 29/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/1 na página 29...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_equivalencia' (Parser TODO)
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_equivalencia' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 1 tabelas. Tipos detectados: ppc_equivalencia
#   [Table Pipeline] Página 30/103 -> Tipo: unknown
#   [Table Pipeline] Página 31/103 -> Tipo: unknown
#   [Table Pipeline] Página 32/103 -> Tipo: unknown
#   [Table Pipeline] Página 33/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 33...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/2 na página 33...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 34/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 34...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 34...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 35/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 35...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/3 na página 35...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 35...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 36/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 36...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 36...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 36...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 37/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 37...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 37...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 38/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 38...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/2 na página 38...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 39/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 39...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 39...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 40/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 40...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 40...
#       [ppc.py] -> Tabela 2 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_ementario
#   [Table Pipeline] Página 41/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 41...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 41...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 42/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 42...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 42...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 42...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 43/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 43...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 43...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 43...
#       [ppc.py] -> Tabela 3 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_ementario
#   [Table Pipeline] Página 44/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 44...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 44...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 45/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 45...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/2 na página 45...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 46/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 46...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 46...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 47/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 47...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/2 na página 47...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 48/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 48...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 48...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 48...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 49/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 49...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 49...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 49...
#       [ppc.py] -> Tabela 3 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_ementario
#   [Table Pipeline] Página 50/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 50...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 50...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 50...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 51/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 51...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 51...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 51...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 52/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 52...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 52...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 52...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 53/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 53...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 53...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 53...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 54/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 54...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 54...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 55/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 55...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/2 na página 55...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 56/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 56...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 56...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 57/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 57...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 57...
#       [ppc.py] -> Tabela 2 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 3/3 na página 57...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 58/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 58...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 58...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 58...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 59/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 59...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 59...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 60/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 60...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/2 na página 60...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 61/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 61...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/3 na página 61...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 61...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 62/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 62...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 62...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 62...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 63/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 63...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 63...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 63...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 64/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 64...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 64...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 64...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 65/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 65...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 65...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 66/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/2 na página 66...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/2 na página 66...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 2 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 67/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 67...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 67...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 67...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 68/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 68...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 68...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 68...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 69/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 69...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 69...
#       [ppc.py] -> Tabela 2 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 3/3 na página 69...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_ementario, ppc_tabela_desconhecida
#   [Table Pipeline] Página 70/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 70...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 70...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 70...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 71/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 71...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 71...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 71...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 72/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 72...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 72...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 72...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 73/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/3 na página 73...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/3 na página 73...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/3 na página 73...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 3 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 74/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/5 na página 74...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/5 na página 74...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/5 na página 74...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 4/5 na página 74...
#       [ppc.py] -> ALERTA: Tabela 4 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 5/5 na página 74...
#       [ppc.py] -> ALERTA: Tabela 5 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 5 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 75/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/5 na página 75...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/5 na página 75...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/5 na página 75...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 4/5 na página 75...
#       [ppc.py] -> ALERTA: Tabela 4 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 5/5 na página 75...
#       [ppc.py] -> ALERTA: Tabela 5 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 5 tabelas. Tipos detectados: ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 76/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/5 na página 76...
#       [ppc.py] -> Tabela 1 identificada como: 'ppc_ementario'
#       [ppc.py] -> ALERTA: Detectou tipo 'ppc_ementario' mas o parser (ex: _parse...()) falhou e retornou 'None'.
#       [ppc.py] Processando Tabela 2/5 na página 76...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/5 na página 76...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 4/5 na página 76...
#       [ppc.py] -> ALERTA: Tabela 4 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 5/5 na página 76...
#       [ppc.py] -> ALERTA: Tabela 5 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Processadas 5 tabelas. Tipos detectados: ppc_ementario, ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida, ppc_tabela_desconhecida
#   [Table Pipeline] Página 77/103 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#       [ppc.py] Processando Tabela 1/5 na página 77...
#       [ppc.py] -> ALERTA: Tabela 1 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 2/5 na página 77...
#       [ppc.py] -> ALERTA: Tabela 2 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 3/5 na página 77...
#       [ppc.py] -> ALERTA: Tabela 3 não correspondeu a nenhum tipo de PPC conhecido (ementa, matriz, etc.).
#       [ppc.py] Processando Tabela 4/5 na página 77...
# ...
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 62/141 -> Tipo: unknown
#   [Table Pipeline] Página 63/141 -> Tipo: unknown
#   [Table Pipeline] Página 64/141 -> Tipo: unknown
#   [Table Pipeline] Página 65/141 -> Tipo: unknown
#   [Table Pipeline] Página 66/141 -> Tipo: unknown
#   [Table Pipeline] Página 67/141 -> Tipo: unknown
#   [Table Pipeline] Página 68/141 -> Tipo: unknown
#   [Table Pipeline] Página 69/141 -> Tipo: unknown
#   [Table Pipeline] Página 70/141 -> Tipo: unknown
#   [Table Pipeline] Página 71/141 -> Tipo: unknown
#   [Table Pipeline] Página 72/141 -> Tipo: unknown
#   [Table Pipeline] Página 73/141 -> Tipo: unknown
#   [Table Pipeline] Página 74/141 -> Tipo: unknown
#   [Table Pipeline] Página 75/141 -> Tipo: unknown
#   [Table Pipeline] Página 76/141 -> Tipo: unknown
#   [Table Pipeline] Página 77/141 -> Tipo: unknown
#   [Table Pipeline] Página 78/141 -> Tipo: unknown
#   [Table Pipeline] Página 79/141 -> Tipo: unknown
#   [Table Pipeline] Página 80/141 -> Tipo: unknown
#   [Table Pipeline] Página 81/141 -> Tipo: unknown
#   [Table Pipeline] Página 82/141 -> Tipo: unknown
#   [Table Pipeline] Página 83/141 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 84/141 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 85/141 -> Tipo: unknown
#   [Table Pipeline] Página 86/141 -> Tipo: unknown
#   [Table Pipeline] Página 87/141 -> Tipo: unknown
#   [Table Pipeline] Página 88/141 -> Tipo: unknown
#   [Table Pipeline] Página 89/141 -> Tipo: unknown
#   [Table Pipeline] Página 90/141 -> Tipo: unknown
#   [Table Pipeline] Página 91/141 -> Tipo: unknown
#   [Table Pipeline] Página 92/141 -> Tipo: unknown
#   [Table Pipeline] Página 93/141 -> Tipo: unknown
#   [Table Pipeline] Página 94/141 -> Tipo: unknown
#   [Table Pipeline] Página 95/141 -> Tipo: unknown
#   [Table Pipeline] Página 96/141 -> Tipo: unknown
#   [Table Pipeline] Página 97/141 -> Tipo: unknown
#   [Table Pipeline] Página 98/141 -> Tipo: unknown
#   [Table Pipeline] Página 99/141 -> Tipo: unknown
#   [Table Pipeline] Página 100/141 -> Tipo: unknown
#   [Table Pipeline] Página 101/141 -> Tipo: unknown
#   [Table Pipeline] Página 102/141 -> Tipo: unknown
#   [Table Pipeline] Página 103/141 -> Tipo: unknown
#   [Table Pipeline] Página 104/141 -> Tipo: unknown
#   [Table Pipeline] Página 105/141 -> Tipo: unknown
#   [Table Pipeline] Página 106/141 -> Tipo: unknown
#   [Table Pipeline] Página 107/141 -> Tipo: unknown
#   [Table Pipeline] Página 108/141 -> Tipo: unknown
#   [Table Pipeline] Página 109/141 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 110/141 -> Tipo: unknown
#   [Table Pipeline] Página 111/141 -> Tipo: unknown
#   [Table Pipeline] Página 112/141 -> Tipo: unknown
#   [Table Pipeline] Página 113/141 -> Tipo: unknown
#   [Table Pipeline] Página 114/141 -> Tipo: unknown
#   [Table Pipeline] Página 115/141 -> Tipo: unknown
#   [Table Pipeline] Página 116/141 -> Tipo: unknown
#   [Table Pipeline] Página 117/141 -> Tipo: unknown
#   [Table Pipeline] Página 118/141 -> Tipo: unknown
#   [Table Pipeline] Página 119/141 -> Tipo: unknown
#   [Table Pipeline] Página 120/141 -> Tipo: unknown
#   [Table Pipeline] Página 121/141 -> Tipo: unknown
#   [Table Pipeline] Página 122/141 -> Tipo: unknown
#   [Table Pipeline] Página 123/141 -> Tipo: unknown
#   [Table Pipeline] Página 124/141 -> Tipo: unknown
#   [Table Pipeline] Página 125/141 -> Tipo: unknown
#   [Table Pipeline] Página 126/141 -> Tipo: unknown
#   [Table Pipeline] Página 127/141 -> Tipo: unknown
#   [Table Pipeline] Página 128/141 -> Tipo: unknown
#   [Table Pipeline] Página 129/141 -> Tipo: unknown
#   [Table Pipeline] Página 130/141 -> Tipo: unknown
#   [Table Pipeline] Página 131/141 -> Tipo: unknown
#   [Table Pipeline] Página 132/141 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 133/141 -> Tipo: unknown
#   [Table Pipeline] Página 134/141 -> Tipo: unknown
#   [Table Pipeline] Página 135/141 -> Tipo: unknown
#   [Table Pipeline] Página 136/141 -> Tipo: unknown
#   [Table Pipeline] Página 137/141 -> Tipo: unknown
#   [Table Pipeline] Página 138/141 -> Tipo: unknown
#   [Table Pipeline] Página 139/141 -> Tipo: unknown
#   [Table Pipeline] Página 140/141 -> Tipo: unknown
#   [Table Pipeline] Página 141/141 -> Tipo: unknown
# Concluído [Table Pipeline]. Resultados: {}
#
# --- Processando: RegulamentoCursosGraduação.pdf ---
# Iniciando [Table Pipeline] para: C:\Users\extre\preprocessamento-pdfs\data\input\RegulamentoCursosGraduação.pdf
#   [Table Pipeline] Página 1/58 -> Tipo: unknown
#   [Table Pipeline] Página 2/58 -> Tipo: unknown
#   [Table Pipeline] Página 3/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 4/58 -> Tipo: unknown
#   [Table Pipeline] Página 5/58 -> Tipo: unknown
#   [Table Pipeline] Página 6/58 -> Tipo: unknown
#   [Table Pipeline] Página 7/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 8/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 8 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 8.
#   [Table Pipeline] Página 9/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 10/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 11/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 12/58 -> Tipo: unknown
#   [Table Pipeline] Página 13/58 -> Tipo: unknown
#   [Table Pipeline] Página 14/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 15/58 -> Tipo: unknown
#   [Table Pipeline] Página 16/58 -> Tipo: unknown
#   [Table Pipeline] Página 17/58 -> Tipo: unknown
#   [Table Pipeline] Página 18/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 19/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 20/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 20 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 20.
#   [Table Pipeline] Página 21/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 21 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 21.
#   [Table Pipeline] Página 22/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 23/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 24/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 25/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 25 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 25.
#   [Table Pipeline] Página 26/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 27/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 28/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 29/58 -> Tipo: unknown
#   [Table Pipeline] Página 30/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 31/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 32/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 33/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 34/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 35/58 -> Tipo: unknown
#   [Table Pipeline] Página 36/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 36 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 36.
#   [Table Pipeline] Página 37/58 -> Tipo: unknown
#   [Table Pipeline] Página 38/58 -> Tipo: unknown
#   [Table Pipeline] Página 39/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 40/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 40 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 40.
#   [Table Pipeline] Página 41/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 41 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 41.
#   [Table Pipeline] Página 42/58 -> Tipo: unknown
#   [Table Pipeline] Página 43/58 -> Tipo: unknown
#   [Table Pipeline] Página 44/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 45/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 45 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 45.
#   [Table Pipeline] Página 46/58 -> Tipo: unknown
#   [Table Pipeline] Página 47/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 47 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 47.
#   [Table Pipeline] Página 48/58 -> Tipo: unknown
#   [Table Pipeline] Página 49/58 -> Tipo: unknown
#   [Table Pipeline] Página 50/58 -> Tipo: unknown
#   [Table Pipeline] Página 51/58 -> Tipo: calendar
# --- [calendar.py] Processando Página 51 ---
#   [calendar.py] Nenhuma tabela encontrada por Camelot na página 51.
#   [Table Pipeline] Página 52/58 -> Tipo: unknown
#   [Table Pipeline] Página 53/58 -> Tipo: unknown
#   [Table Pipeline] Página 54/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 55/58 -> Tipo: unknown
#   [Table Pipeline] Página 56/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
#   [Table Pipeline] Página 57/58 -> Tipo: unknown
#   [Table Pipeline] Página 58/58 -> Tipo: ppc
#     -> Chamando processador 'ppc.py'...
#     -> ALERTA: 'ppc.py' foi chamado, mas não retornou nenhuma tabela ('parsed_data_list' está vazia).
#     -> Sumário do 'ppc.py': Nenhuma tabela encontrada nesta página pelo Camelot.
# Concluído [Table Pipeline]. Resultados: {}
#
#
# ==================================================
# --- PROCESSAMENTO DE INTEGRAÇÃO CONCLUÍDO ---
# ==================================================
# Sucesso: 7 arquivos
# Falhas:  0 arquivos
#
# --- RESUMO DETALHADO POR ARQUIVO ---
#
# [SUCESSO] Ciencia-da-computacao-01-2025_com_sala_MkIII.pdf
#   - JSON Alvo:   Ciencia-da-computacao-01-2025_com_sala_MkIII_output.jsonl (Editado)
#   - Tabelas Add: 7
#   - Limpeza ('table' singular): Não
#
# [SUCESSO] Estatuto - Fevereiro 2025_.pdf
#   - JSON Alvo:   Estatuto - Fevereiro 2025__output.jsonl (Editado)
#   - Tabelas Add: 0
#   - Limpeza ('table' singular): Não
#
# [SUCESSO] Estágio.pdf
#   - JSON Alvo:   Estágio_output.jsonl (Editado)
#   - Tabelas Add: 0
#   - Limpeza ('table' singular): Não
#
# [SUCESSO] PPCBCC2019.pdf
#   - JSON Alvo:   PPCBCC2019_output.jsonl (Editado)
#   - Tabelas Add: 4
#   - Limpeza ('table' singular): Não
#
# [SUCESSO] Regimento Interno dos Campi.pdf
#   - JSON Alvo:   Regimento Interno dos Campi_output.jsonl (Editado)
#   - Tabelas Add: 0
#   - Limpeza ('table' singular): Não
#
# [SUCESSO] REGIMENTO_GERAL_FEVEREIRO_DE_2025.pdf
#   - JSON Alvo:   REGIMENTO_GERAL_FEVEREIRO_DE_2025_output.jsonl (Editado)
#   - Tabelas Add: 0
#   - Limpeza ('table' singular): Não
#
# [SUCESSO] RegulamentoCursosGraduação.pdf
#   - JSON Alvo:   RegulamentoCursosGraduação_output.jsonl (Editado)
#   - Tabelas Add: 0
#   - Limpeza ('table' singular): Não
